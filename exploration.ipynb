# %%
import pandas as pd
import numpy as np
import re
pd.set_option('display.max_columns', None)

# %%
df_empreendimento = pd.read_json("dadospelt/vw_empreendimento.json")
df_empreendimento = pd.json_normalize(df_empreendimento['vw_empreendimento'])

# %%
df_empreendimento[['id_empreendimento', 'origem_ajustada', 'tipos_infraestruturas','intervencao_principal', 'nome_empreendimento']]
# Out:
#       id_empreendimento origem_ajustada  \
# 0                     1       PELT 2007
# 1                     2       PELT 2007
# 2                     3       PELT 2007
# 3                     4       PELT 2007
# 4                     5       PELT 2007
# ...                 ...             ...
# 1937               1889         CODEMGE
# 1938               1890         CODEMGE
# 1939               1891         CODEMGE
# 1940               1932          GERDAU
# 1941               1948          GASMIG
#
#                         tipos_infraestruturas  \
# 0     {"Faixa adicional","Trecho rodoviário"}
# 1                       {"Trecho rodoviário"}
# 2                       {"Trecho rodoviário"}
# 3     {"Faixa adicional","Trecho rodoviário"}
# 4                       {"Trecho rodoviário"}
# ...                                       ...
# 1937                               {Oleoduto}
# 1938                               {Gasoduto}
# 1939                               {Gasoduto}
# 1940                             {Mineroduto}
# 1941          {Gasoduto,"Terminal de Cargas"}
#
#                 intervencao_principal  \
# 0      Ampliação de trecho rodoviário
# 1     Manutenção de trecho rodoviário
# 2     Manutenção de trecho rodoviário
# 3      Ampliação de trecho rodoviário
# 4      Ampliação de trecho rodoviário
# ...                               ...
# 1937              Operação de dutovia
# 1938              Operação de dutovia
# 1939              Operação de dutovia
# 1940              Operação de dutovia
# 1941           Implantação de dutovia
#
#                                     nome_empreendimento
# 0                        BR 040 – entre BH e div. MG/GO
# 1                        BR 040 – entre BH e div. MG/RJ
# 2     BR 262 – entre Entr. p/ Bela Vista de Minas e ...
# 3                        BR 262 – entre Betim e Uberaba
# 4              BR 381 – entre BH e Governador Valadares
# ...                                                 ...
# 1937  Operação de dutovia em OSBRA 20 POL (REPLAN - ...
# 1938        Operação de dutovia em GASBEL (REDUC/REGAP)
# 1939          Operação de dutovia em Paulínia-Jacutinga
# 1940  Implantação de Mineroduto em Ouro Preto/MG - O...
# 1941                       Gasoduto Gasmig Centro Oeste
#
# [1942 rows x 5 columns]

# %%
df_extensao = pd.read_json("dadospelt/mvw_geo_extensao.json")
df_extensao = pd.json_normalize(df_extensao['mvw_geo_extensao'])

# %%
df_extensao['extensao_km'] = pd.to_numeric(df_extensao['extensao_km'], errors='coerce')
df_extensao['extensao_km'] = df_extensao['extensao_km'].replace([np.inf, -np.inf], np.nan)
df_extensao['extensao_km'] = df_extensao['extensao_km'].round()
df_extensao['extensao_km'] = df_extensao['extensao_km'].astype('Int64')

# %%
df_extensao
# Out:
#       id_empreendimento  extensao_km
# 0                     1   460.959844
# 1                     2   299.098993
# 2                     3   192.792069
# 3                     4   446.391005
# 4                     5   307.835913
# ...                 ...          ...
# 1934               1889   784.378080
# 1935               1890   352.093811
# 1936               1891    91.316447
# 1937               1932    14.657760
# 1938               1948   186.879689
#
# [1939 rows x 2 columns]

# %%
df_gestao_carteiras = pd.read_json("dadospelt/vw_gestao_carteiras.json")
df_gestao_carteiras = pd.json_normalize(df_gestao_carteiras['vw_gestao_carteiras'])
df_gestao_carteiras[['id_empreendimento', 'impacto_avaliado_1_pond_cenario', 'receita']]
# Out:
#       id_empreendimento impacto_avaliado_1_pond_cenario       receita
# 0                    11                    Alto impacto  1.772959e+09
# 1                    12                   Médio impacto  1.725776e+09
# 2                    13                   Médio impacto  4.284536e+09
# 3                    18                    Alto impacto  3.525546e+09
# 4                    35                   Médio impacto           NaN
# ...                 ...                             ...           ...
# 1673               1964                    Alto impacto           NaN
# 1674               1970                   Médio impacto           NaN
# 1675                 29                    Alto impacto  3.114839e+09
# 1676                417                    Alto impacto           NaN
# 1677                 31                    Alto impacto  2.498975e+09
#
# [1678 rows x 3 columns]

# %%
df = pd.read_parquet("dados_consolidados.parquet")

# %%
df[df['extensao_km'] > 999]
# Out:
#       id_empreendimento origem_ajustada  \
# 11                   56            ANTT
# 27                  112        PNL 2035
# 1510                 57            ANTT
# 1514                 82            ANTT
# 1524                107            ANTT
# 1525                108            ANTT
# 1527                113            ANTT
# 1537                147         MT_SNTF
# 1547                726        PEF 2021
# 1563                742        PEF 2021
# 1613                122         INFRASA
# 1663                993        PIO 2022
#
#                                   tipos_infraestruturas  \
# 11                                  [Trecho rodoviário]
# 27                                  [Trecho rodoviário]
# 1510  [Material rodante para Transporte de Cargas, P...
# 1514  [Material rodante para Transporte de Cargas, P...
# 1524  [Material rodante para Transporte de Cargas, P...
# 1525  [Material rodante para Transporte de Cargas, P...
# 1527  [Material rodante para Transporte de Cargas, P...
# 1537  [Material rodante para Transporte de Cargas, P...
# 1547  [Material rodante para Transporte de Cargas, P...
# 1563  [Material rodante para Transporte de Cargas, P...
# 1613                               [Trecho hidroviário]
# 1663                               [Terminal de Cargas]
#
#                   intervencao_principal  \
# 11      Manutenção de trecho rodoviário
# 27       Ampliação de trecho rodoviário
# 1510    Ampliação de trecho ferroviário
# 1514  Implantação de trecho ferroviário
# 1524  Implantação de trecho ferroviário
# 1525    Ampliação de trecho ferroviário
# 1527    Ampliação de trecho ferroviário
# 1537    Ampliação de trecho ferroviário
# 1547  Implantação de trecho ferroviário
# 1563  Implantação de trecho ferroviário
# 1613  Implantação de trecho hidroviário
# 1663             Implantação de dutovia
#
#                                     nome_empreendimento        setor  \
# 11    Manutenção de trecho rodoviário na BR-060/153/...   Rodoviário
# 27          Ampliação de trecho rodoviário na BR-251/MG   Rodoviário
# 1510  Ampliação de trecho ferroviário em Renovação d...  Ferroviário
# 1514  Implantação de trecho ferroviário de Implantaç...  Ferroviário
# 1524  Implantação de trecho ferroviário em Ferrovia ...  Ferroviário
# 1525  Ampliação de trecho ferroviário em Malha Centr...  Ferroviário
# 1527  Renovação da Concessão da Malha Centro-Leste (...  Ferroviário
# 1537  Ampliação de trecho ferroviário em Linha Corin...  Ferroviário
# 1547  Implantação de trecho ferroviário em FC 39 Cor...  Ferroviário
# 1563  Implantação de trecho ferroviário em FC 101 An...  Ferroviário
# 1613  Manutenção de trecho hidroviário na Hidrovia d...  Hidroviário
# 1663  Implantação de dutovia em Oleoduto Uberaba/MG ...   Dutoviário
#
#                         descr_status_empreendimento  \
# 11                         Contratado - em execução
# 27                                           Estudo
# 1510                       Contratado - em execução
# 1514                                         Estudo
# 1524                       Contratado - em execução
# 1525                       Contratado - em execução
# 1527  Em contratação (Licitação/Autorização/Adesão)
# 1537                                         Estudo
# 1547                                      Concepção
# 1563                                      Concepção
# 1613                       Contratado - em execução
# 1663                                      Concepção
#
#              natureza_empreendimento esfera_acao  \
# 11    Transporte de Cargas e Pessoas     Federal
# 27    Transporte de Cargas e Pessoas     Federal
# 1510            Transporte de Cargas     Federal
# 1514            Transporte de Cargas     Federal
# 1524            Transporte de Cargas     Federal
# 1525            Transporte de Cargas     Federal
# 1527            Transporte de Cargas     Federal
# 1537            Transporte de Cargas     Federal
# 1547            Transporte de Cargas     Federal
# 1563            Transporte de Cargas     Federal
# 1613  Transporte de Cargas e Pessoas     Federal
# 1663            Transporte de Cargas     Federal
#
#                                         grupo_modelagem  \
# 11                Caso geral - infraestruturas lineares
# 27    Empreendimentos rodoviários de execução públic...
# 1510              Caso geral - infraestruturas lineares
# 1514              Caso geral - infraestruturas lineares
# 1524              Caso geral - infraestruturas lineares
# 1525              Caso geral - infraestruturas lineares
# 1527              Caso geral - infraestruturas lineares
# 1537              Caso geral - infraestruturas lineares
# 1547              Caso geral - infraestruturas lineares
# 1563              Caso geral - infraestruturas lineares
# 1613              Caso geral - infraestruturas lineares
# 1663              Caso geral - infraestruturas lineares
#
#      responsavel_gestao_infraestrutura      tirm        viabilidade  \
# 11                            Concebra -0.014421  Baixa viabilidade
# 27                                DNIT       NaN      Não se aplica
# 1510                MRS Logística S.A.  0.597367   Alta viabilidade
# 1514                        Greenfield -0.234338  Baixa viabilidade
# 1524           Rumo Malha Central S.A.  0.445181   Alta viabilidade
# 1525                     VLI Logística  0.594949   Alta viabilidade
# 1527                     VLI Logística  0.594949   Alta viabilidade
# 1537                     VLI Logística -0.078120  Baixa viabilidade
# 1547                           Vale SA -0.078120  Baixa viabilidade
# 1563                        Greenfield  0.276893   Alta viabilidade
# 1613                              DNIT       NaN      Não se aplica
# 1663                        Greenfield       NaN      Não se aplica
#
#       dimensao_financeira  dimensao_socioeconomica_pond  dimensao_estrategica  \
# 11               1.000000                      0.219574              0.124383
# 27               0.000000                      0.231172              0.068208
# 1510             1.000000                      0.481059              0.267317
# 1514             0.000000                      0.264357              0.047485
# 1524             0.817451                      0.508567              0.039843
# 1525             1.000000                      0.399139              0.443063
# 1527             1.000000                      0.508438              0.500000
# 1537             0.187928                      0.410097              0.060257
# 1547             0.187928                      0.452921              0.059150
# 1563             0.615003                      0.414094              0.093183
# 1613             0.000000                      0.262344              0.366819
# 1663             0.000000                      0.451893              0.054952
#
#       ic_1_pond                                          municipio  Rodovias  \
# 11     0.249585  [Anápolis, São Gonçalo do Pará, Goiatuba, Bom ...  [BR-060]
# 27     0.067992  [Santa Cruz de Salinas, Dom Bosco, Unaí, Monte...  [BR-251]
# 1510   0.372476  [Alfredo Vasconcelos, Rio Acima, Paraíba do Su...        []
# 1514   0.070531  [Itacambira, Unaí, Montes Claros, Teófilo Oton...        []
# 1524   0.214536  [São Simão, Paraíso do Tocantins, Anápolis, Pa...        []
# 1525   0.353056  [Rio do Antônio, Brumado, Muritiba, Divinópoli...        []
# 1527   0.391045  [Rio do Antônio, Brumado, Muritiba, Divinópoli...        []
# 1537   0.144076  [Engenheiro Navarro, Buenópolis, Salvador, Mon...        []
# 1547   0.153420  [Engenheiro Navarro, Buenópolis, Salvador, Mon...        []
# 1563   0.238743  [Dom Bosco, Unaí, Conceição do Mato Dentro, An...        []
# 1613   0.145644  [São Simão, Castilho, Paulicéia, Marechal Când...        []
# 1663   0.114362  [Pedro Gomes, Planura, Santo Antônio do Leverg...        []
#
#                                link_formulario         capex          opex  \
# 11     https://forms.pelt.mg.gov.br/avaliar/56  1.348048e+10  8.853483e+09
# 27    https://forms.pelt.mg.gov.br/avaliar/112  4.665797e+09  4.882833e+09
# 1510   https://forms.pelt.mg.gov.br/avaliar/57  9.687000e+09  6.766000e+10
# 1514   https://forms.pelt.mg.gov.br/avaliar/82  1.422000e+10  7.815000e+09
# 1524  https://forms.pelt.mg.gov.br/avaliar/107  3.639884e+09  0.000000e+00
# 1525  https://forms.pelt.mg.gov.br/avaliar/108  0.000000e+00  7.243930e+08
# 1527  https://forms.pelt.mg.gov.br/avaliar/113  2.898924e+08  4.236144e+10
# 1537  https://forms.pelt.mg.gov.br/avaliar/147  6.218544e+09  7.815000e+09
# 1547  https://forms.pelt.mg.gov.br/avaliar/726  1.622466e+10  8.805000e+09
# 1563  https://forms.pelt.mg.gov.br/avaliar/742  1.501176e+10  1.058700e+10
# 1613  https://forms.pelt.mg.gov.br/avaliar/122  5.538512e+07  6.490990e+09
# 1663  https://forms.pelt.mg.gov.br/avaliar/993  9.916722e+09  8.243100e+09
#
#       carteira_classificada  \
# 11                      1.0
# 27                      1.0
# 1510                    1.0
# 1514                    0.0
# 1524                    1.0
# 1525                    1.0
# 1527                    1.0
# 1537                    0.0
# 1547                    1.0
# 1563                    1.0
# 1613                    1.0
# 1663                    1.0
#
#                         regiao_geografica_intermediaria  extensao_km  \
# 11    [Belo Horizonte, Uberaba, Uberlândia, Divinópo...         1179
# 27    [Vitória da Conquista, Montes Claros, Teófilo ...         1019
# 1510  [Belo Horizonte, Juíz de Fora, Barbacena, Rio ...         1901
# 1514  [Montes Claros, Teófilo Otoni, Patos de Minas,...         1067
# 1524  [Palmas, Araguaína, Gurupi, Imperatriz, Uberab...         1542
# 1525  [Petrolina, Aracaju, Itabaiana, Salvador, Sant...         7182
# 1527  [Petrolina, Aracaju, Itabaiana, Salvador, Sant...         7830
# 1537  [Salvador, Santo Antônio de Jesus, Vitória da ...         1357
# 1547  [Salvador, Santo Antônio de Jesus, Vitória da ...         1318
# 1563  [Belo Horizonte, Montes Claros, Teófilo Otoni,...         1540
# 1613  [Uberaba, Uberlândia, Presidente Prudente, Ara...         1364
# 1663  [Uberaba, Uberlândia, Campo Grande, Cuiabá, Ro...         1380
#
#      impacto_avaliado_1_pond_cenario       receita
# 11                      Alto impacto  1.193667e+10
# 27                      Alto impacto  4.712352e+09
# 1510                    Alto impacto  2.065460e+12
# 1514                   Baixo impacto  5.555220e+05
# 1524                   Médio impacto  3.096470e+12
# 1525                    Alto impacto  7.964490e+11
# 1527                    Alto impacto  9.097310e+11
# 1537                   Baixo impacto  2.093360e+11
# 1547                   Médio impacto  2.206990e+11
# 1563                   Médio impacto  1.411720e+12
# 1613                   Médio impacto           NaN
# 1663                    Alto impacto           NaN

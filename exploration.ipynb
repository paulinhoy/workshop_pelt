# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df_empreendimento = pd.read_json("dadospelt/vw_empreendimento.json")
df_empreendimento = pd.json_normalize(df_empreendimento['vw_empreendimento'])

# %%
df_empreendimento[['id_empreendimento', 'origem_ajustada', 'tipos_infraestruturas', 'nome_empreendimento']]
# Out:
#       id_empreendimento origem_ajustada  \
# 0                     1       PELT 2007
# 1                     2       PELT 2007
# 2                     3       PELT 2007
# 3                     4       PELT 2007
# 4                     5       PELT 2007
# ...                 ...             ...
# 1937               1889         CODEMGE
# 1938               1890         CODEMGE
# 1939               1891         CODEMGE
# 1940               1932          GERDAU
# 1941               1948          GASMIG
#
#                         tipos_infraestruturas  \
# 0     {"Faixa adicional","Trecho rodoviário"}
# 1                       {"Trecho rodoviário"}
# 2                       {"Trecho rodoviário"}
# 3     {"Faixa adicional","Trecho rodoviário"}
# 4                       {"Trecho rodoviário"}
# ...                                       ...
# 1937                               {Oleoduto}
# 1938                               {Gasoduto}
# 1939                               {Gasoduto}
# 1940                             {Mineroduto}
# 1941          {Gasoduto,"Terminal de Cargas"}
#
#                                     nome_empreendimento
# 0                        BR 040 – entre BH e div. MG/GO
# 1                        BR 040 – entre BH e div. MG/RJ
# 2     BR 262 – entre Entr. p/ Bela Vista de Minas e ...
# 3                        BR 262 – entre Betim e Uberaba
# 4              BR 381 – entre BH e Governador Valadares
# ...                                                 ...
# 1937  Operação de dutovia em OSBRA 20 POL (REPLAN - ...
# 1938        Operação de dutovia em GASBEL (REDUC/REGAP)
# 1939          Operação de dutovia em Paulínia-Jacutinga
# 1940  Implantação de Mineroduto em Ouro Preto/MG - O...
# 1941                       Gasoduto Gasmig Centro Oeste
#
# [1942 rows x 4 columns]

# %%
df_extensao = pd.read_json("dadospelt/mvw_geo_extensao.json")
df_extensao = pd.json_normalize(df_extensao['mvw_geo_extensao'])

# %%
df_extensao['extensao_km'] = pd.to_numeric(df_extensao['extensao_km'], errors='coerce')
df_extensao['extensao_km'] = df_extensao['extensao_km'].replace([np.inf, -np.inf], np.nan)
df_extensao['extensao_km'] = df_extensao['extensao_km'].round()
df_extensao['extensao_km'] = df_extensao['extensao_km'].astype('Int64')

# %%
df_extensao
# Out:
#       id_empreendimento  extensao_km
# 0                     1   460.959844
# 1                     2   299.098993
# 2                     3   192.792069
# 3                     4   446.391005
# 4                     5   307.835913
# ...                 ...          ...
# 1934               1889   784.378080
# 1935               1890   352.093811
# 1936               1891    91.316447
# 1937               1932    14.657760
# 1938               1948   186.879689
#
# [1939 rows x 2 columns]

# %%
df_gestao_carteiras = pd.read_json("dadospelt/vw_gestao_carteiras.json")
df_gestao_carteiras = pd.json_normalize(df_gestao_carteiras['vw_gestao_carteiras'])
df_gestao_carteiras[['id_empreendimento', 'impacto_avaliado_1_pond_cenario', 'receita']]
# Out:
#       id_empreendimento impacto_avaliado_1_pond_cenario       receita
# 0                    11                    Alto impacto  1.772959e+09
# 1                    12                   Médio impacto  1.725776e+09
# 2                    13                   Médio impacto  4.284536e+09
# 3                    18                    Alto impacto  3.525546e+09
# 4                    35                   Médio impacto           NaN
# ...                 ...                             ...           ...
# 1673               1964                    Alto impacto           NaN
# 1674               1970                   Médio impacto           NaN
# 1675                 29                    Alto impacto  3.114839e+09
# 1676                417                    Alto impacto           NaN
# 1677                 31                    Alto impacto  2.498975e+09
#
# [1678 rows x 3 columns]

# %%
df = pd.read_parquet("dados_consolidados.parquet")

# %%
df
# Out:
#       id_empreendimento origem_ajustada  \
# 0                    11       PELT 2007
# 1                    12       PELT 2007
# 2                    13       PELT 2007
# 3                    18       PELT 2007
# 4                    29       PELT 2007
# ...                 ...             ...
# 1673               1889         CODEMGE
# 1674               1890         CODEMGE
# 1675               1891         CODEMGE
# 1676               1932          GERDAU
# 1677               1948          GASMIG
#
#                         tipos_infraestruturas  \
# 0     {"Faixa adicional","Trecho rodoviário"}
# 1     {"Faixa adicional","Trecho rodoviário"}
# 2     {"Faixa adicional","Trecho rodoviário"}
# 3                       {"Trecho rodoviário"}
# 4     {"Faixa adicional","Trecho rodoviário"}
# ...                                       ...
# 1673                               {Oleoduto}
# 1674                               {Gasoduto}
# 1675                               {Gasoduto}
# 1676                             {Mineroduto}
# 1677          {Gasoduto,"Terminal de Cargas"}
#
#                                     nome_empreendimento       setor  \
# 0     Ampliação de trecho rodoviário na BR 153: div....  Rodoviário
# 1     Ampliação de trecho rodoviário na BR 251: Mont...  Rodoviário
# 2     Ampliação de trecho rodoviário na BR 365: Uber...  Rodoviário
# 3     AMG-1520/AMG-1550/BR-146/MG-459/BR-267/MG-290/...  Rodoviário
# 4     AMG-2535/AMG-2540/BR-364/BR-497/LMG-732/LMG-81...  Rodoviário
# ...                                                 ...         ...
# 1673  Operação de dutovia em OSBRA 20 POL (REPLAN - ...  Dutoviário
# 1674        Operação de dutovia em GASBEL (REDUC/REGAP)  Dutoviário
# 1675          Operação de dutovia em Paulínia-Jacutinga  Dutoviário
# 1676  Implantação de Mineroduto em Ouro Preto/MG - O...  Dutoviário
# 1677                       Gasoduto Gasmig Centro Oeste  Dutoviário
#
#      descr_status_empreendimento         natureza_empreendimento esfera_acao  \
# 0                      Concepção  Transporte de Cargas e Pessoas     Federal
# 1                      Concepção  Transporte de Cargas e Pessoas     Federal
# 2                      Concepção  Transporte de Cargas e Pessoas     Federal
# 3                      Concepção  Transporte de Cargas e Pessoas    Estadual
# 4                      Concepção  Transporte de Cargas e Pessoas    Estadual
# ...                          ...                             ...         ...
# 1673    Contratado - em execução            Transporte de Cargas     Federal
# 1674    Contratado - em execução            Transporte de Cargas     Federal
# 1675    Contratado - em execução            Transporte de Cargas     Federal
# 1676                   Concepção            Transporte de Cargas     Federal
# 1677    Contratado - em execução            Transporte de Cargas    Estadual
#
#                             grupo_modelagem responsavel_gestao_infraestrutura  \
# 0     Caso geral - infraestruturas lineares                  Triunfo Concebra
# 1     Caso geral - infraestruturas lineares                              DNIT
# 2     Caso geral - infraestruturas lineares                     EPR Triângulo
# 3     Caso geral - infraestruturas lineares                            DER-MG
# 4     Caso geral - infraestruturas lineares                            DER-MG
# ...                                     ...                               ...
# 1673  Caso geral - infraestruturas lineares                           UN-BSOL
# 1674  Caso geral - infraestruturas lineares                           UN-SEAL
# 1675  Caso geral - infraestruturas lineares                    DT/REGIONAL SE
# 1676  Caso geral - infraestruturas lineares                            GERDAU
# 1677  Caso geral - infraestruturas lineares                            GASMIG
#
#           tirm        viabilidade  dimensao_financeira  \
# 0     0.112115   Alta viabilidade             0.829848
# 1     0.026073  Média viabilidade             0.527264
# 2     0.007344  Média viabilidade             0.461397
# 3    -0.007514  Baixa viabilidade             1.000000
# 4     0.075304  Média viabilidade             1.000000
# ...        ...                ...                  ...
# 1673       NaN      Não se aplica             0.000000
# 1674       NaN      Não se aplica             0.000000
# 1675       NaN      Não se aplica             0.000000
# 1676       NaN      Não se aplica             0.000000
# 1677       NaN      Não se aplica             0.000000
#
#       dimensao_socioeconomica_pond  dimensao_estrategica  ic_1_pond  \
# 0                         0.158500              0.029909   0.209693
# 1                         0.210893              0.028751   0.160255
# 2                         0.204966              0.065963   0.154470
# 3                         0.115430              0.038716   0.210941
# 4                         0.208451              0.044454   0.247993
# ...                            ...                   ...        ...
# 1673                      0.161004              0.027476   0.042615
# 1674                      0.194942              0.013377   0.046891
# 1675                      0.141889              0.000637   0.031976
# 1676                      0.147287              0.000000   0.033036
# 1677                      0.376222              0.000000   0.084386
#
#                                               municipio  \
# 0     [Itumbiara, Monte Alegre de Minas, Comendador ...
# 1     [Salinas, Fruta de Leite, Francisco Sá, Santa ...
# 2     [Patrocínio, São Gonçalo do Abaeté, Indianópol...
# 3     [Andradas, Pouso Alegre, Borda da Mata, Monte ...
# 4     [Planura, Pirajuba, Conceição das Alagoas, Itu...
# ...                                                 ...
# 1673  [São Joaquim da Barra, Hidrolândia, São Simão,...
# 1674  [Queluzito, Cristiano Otoni, Sarzedo, Jeceaba,...
# 1675  [Santo Antônio de Posse, Mogi-Mirim, Holambra,...
# 1676                            [Ouro Preto, Congonhas]
# 1677  [Juatuba, Igarapé, Itaúna, Carmo do Cajuru, Di...
#
#                                                Rodovias  \
# 0                                              [BR-153]
# 1                                      [BR-251, BR-116]
# 2                                              [BR-365]
# 3     [MG-455, AMG-1520, MG-290, MG-295, MGT-482, BR...
# 4     [AMG-2535, MG-427, MGT-497, AMG-2540, MG-426, ...
# ...                                                 ...
# 1673                                                 []
# 1674                                                 []
# 1675                                                 []
# 1676                                                 []
# 1677                                                 []
#
#                                 link_formulario         capex          opex  \
# 0       https://forms.pelt.mg.gov.br/avaliar/11  1.268445e+09  1.123160e+09
# 1       https://forms.pelt.mg.gov.br/avaliar/12  1.586033e+09  1.540566e+09
# 2       https://forms.pelt.mg.gov.br/avaliar/13  4.311709e+09  2.925072e+09
# 3       https://forms.pelt.mg.gov.br/avaliar/18  3.964090e+09  1.320657e+09
# 4       https://forms.pelt.mg.gov.br/avaliar/29           NaN           NaN
# ...                                         ...           ...           ...
# 1673  https://forms.pelt.mg.gov.br/avaliar/1889           NaN           NaN
# 1674  https://forms.pelt.mg.gov.br/avaliar/1890           NaN           NaN
# 1675  https://forms.pelt.mg.gov.br/avaliar/1891           NaN           NaN
# 1676  https://forms.pelt.mg.gov.br/avaliar/1932  9.553180e+08  8.597862e+08
# 1677  https://forms.pelt.mg.gov.br/avaliar/1948  7.800000e+08  7.020000e+08
#
#       carteira_classificada  \
# 0                       1.0
# 1                       1.0
# 2                       1.0
# 3                       1.0
# 4                       1.0
# ...                     ...
# 1673                    0.0
# 1674                    0.0
# 1675                    0.0
# 1676                    0.0
# 1677                    1.0
#
#                         regiao_geografica_intermediaria  extensao_km  \
# 0                      [Uberaba, Uberlândia, Itumbiara]   235.624964
# 1                        [Montes Claros, Teófilo Otoni]   321.565877
# 2           [Montes Claros, Uberlândia, Patos de Minas]   610.558986
# 3                                        [Pouso Alegre]   275.924304
# 4          [Uberaba, Uberlândia, São José do Rio Preto]   507.988161
# ...                                                 ...          ...
# 1673  [Uberaba, Uberlândia, Ribeirão Preto, Araraqua...   784.378080
# 1674  [Belo Horizonte, Juíz de Fora, Barbacena, Rio ...   352.093811
# 1675                           [Pouso Alegre, Campinas]    91.316447
# 1676                        [Belo Horizonte, Barbacena]    14.657760
# 1677                      [Belo Horizonte, Divinópolis]   186.879689
#
#      impacto_avaliado_1_pond_cenario       receita
# 0                       Alto impacto  1.772959e+09
# 1                      Médio impacto  1.725776e+09
# 2                      Médio impacto  4.284536e+09
# 3                       Alto impacto  3.525546e+09
# 4                       Alto impacto  3.114839e+09
# ...                              ...           ...
# 1673                   Baixo impacto           NaN
# 1674                   Baixo impacto           NaN
# 1675                   Baixo impacto           NaN
# 1676                   Baixo impacto           NaN
# 1677                   Médio impacto           NaN
#
# [1678 rows x 26 columns]
